# %%
#Leave this empty!

# %% [markdown]
# ---
#
#
# *This answer sheet is used for answering the excercises of the assignment "Dynamics of Love" (Semester 2/Academic Year 2022-2023) - © Thinh Nguyen*
#
# *Student(s):*
# $$
# \begin{array}{lllll}
# \hline
# \textbf{No.} & \textbf{Fullname} & \textbf{ID} & \textbf{Group} & \textbf{Contribution}\\
# \hline
# 1 & \textrm{Bùi Nguyễn Thành Luân } & 2111700 & \textrm{L01} & 20\% \\
# 2 & \textrm{Nguyễn Nguyên Nguyễn} & 2110405 & \textrm{L01} & 20\% \\
# 3 & \textrm{Lê Hà Thanh Sơn} & 1813842 & \textrm{L01} & 20\% \\
# 4 & \textrm{Nguyễn Hữu Thông} & 2114917 & \textrm{L01} & 20\% \\
# 5 & \textrm{Nguyễn Xuân Triều} & 2110610 & \textrm{L01} & 20\% \\
# \hline
# \end{array}
# $$
#
# \\
#
# For these exercises use the following system of ODEs (Ordinary Differential Equations)
# $$
# \begin{cases}
#   \dot{\textbf{x}} = \textbf{f}(t, \textbf{x}),\\
#   \textbf{x}(0) = \textbf{x}_0,
# \end{cases}
# $$
# where $\textbf{x}=\textbf{x}(t)$ a 2-dimensional real vector dependent on time $t\ge 0$ and $\textbf{f}$ is a 2-dimensional real-vector-valued function dependent on time $t$ and $\textbf{x}$. As an example, $\textbf{f}(t, \textbf{x})=A\textbf{x}$, where $A$ is a constant $2\times 2$ matrix with real entries.
#
# Let's call the system above system (1).
#
# ---

# %%
#Leave this empty!

# %% [markdown]
# **Important notes:**
#
#
# *   For each small question, if the answer is not complete, the score of the answer will be **50% of the score of the complete part of the answer**. If the answer is not readable, the score of it will be **0**.
# *   For Exercise 4, use only the libraries numpy and matplotlib. For the function *jacobian_x* and the function *solve_system*, do not use any function that are similar to them provided in numpy.

# %%
#Leave this empty!

# %% [markdown]
# # **Exercise 1 (*2.0 points*)**

# %% [markdown]
# 1) Find the 3 formulae of the exact solution to the system (1) in the constant linear case where $\textbf{f}(t, \textbf{x})=A\textbf{x}$ in terms of the eigenvalues $\lambda_1$ and $\lambda_2$ of $A$. All of the coefficients must be written explicitly without leading to any equation! (*1.0 point*)

# %% [markdown]
# *Answer:*
#
#   Set $A = \begin{pmatrix} a_{11} & a_{12} \\ a_{21} & a_{22} \end{pmatrix}$ and $\textbf{x}_0 = \textbf{x}(0) = \begin{pmatrix} b_1 \\ b_2 \end{pmatrix}$
#
# 1.   $\lambda_1, \lambda_2\in\mathbb R, \lambda_1\ne \lambda_2$:
#
#   With $a_{12} \neq 0$
#   $$
#     \textbf{x}(t) = \frac{(a_{11}-\lambda_2) b_1+a_{12} b_2}{a_{12} (\lambda_1- \lambda_2)} e^{\lambda_1 t} \begin{pmatrix} a_{12} \\ \lambda_1-a_{11} \end{pmatrix} + \frac{(a_{11}-\lambda_1) b_1+a_{12} b_2}{a_{12} (\lambda_2- \lambda_1)} e^{\lambda_2 t} \begin{pmatrix} a_{12} \\ \lambda_2-a_{11} \end{pmatrix}
#   $$
#   With $a_{12} = 0$, we have $a_{11} \neq a_{22}$
#   $$
#     \textbf{x}(t)=\frac{b_1}{a_{11}-a_{22}} e^{a_{11} t} \begin{pmatrix} a_{11} - a_{22} \\ a_{21} \end{pmatrix} + \left( \frac{a_{21}}{a_{22}-a_{11}} b_1+b_2 \right) e^{a_{22} t} \begin{pmatrix} 0 \\ 1 \end{pmatrix}
#   $$
# 2.   $\lambda_1, \lambda_2\in\mathbb R, \lambda_1 = \lambda_2 = \lambda$:
#
#   With $a_{12} \neq 0$
#   $$
#     \textbf{x}(t) = e^{\lambda t} \begin{pmatrix} b_1 \\ b_2 \end{pmatrix} + \frac{a_{12} b_2 - (\lambda - a_{11}) b_1}{a_{12}} t e^{\lambda t} \begin{pmatrix} a_{12} \\ \lambda - a_{11} \end{pmatrix}
#   $$
#
#   With $ a_{12} = 0 $
#   $$
#     \textbf{x}(t) = e^{\lambda t} \begin{pmatrix} b_1 \\ b_2 \end{pmatrix} + t e^{\lambda t} \begin{pmatrix} 0 \\ a_{21} b_1 \end{pmatrix}
#   $$
#
# 3. $\lambda_1, \lambda_2\in\mathbb C, \lambda_1= a+ib, \lambda_2=a-ib$:
#
#   $$
#     \textbf{x}(t) = e^{at} \cos(bt) \begin{pmatrix} b_1 \\ b_2 \end{pmatrix} + e^{at} i \sin(bt) \left[ 2 \frac{(a_{11}-\lambda_2) b_1+a_{12} b_2}{a_{12} (\lambda_1- \lambda_2)} \begin{pmatrix} a_{12} \\ \lambda_1-a_{11} \end{pmatrix} - \begin{pmatrix} b_1 \\ b_2 \end{pmatrix} \right]
#   $$

# %% [markdown]
# 2) Complete the phase-portrait table with these types: Spiral, Center, Saddle, and Node. (*1.0 point*)

# %% [markdown]
# *Answer:*
#
# $$
# \begin{array}{ccccc}
# \hline
# \textrm{Re}\,\lambda_1 & \textrm{Re}\,\lambda_2 & |\textrm{Im}\,\lambda_1| & |\textrm{Im}\,\lambda_2| & \textbf{Type}\\
# \hline
# + & + & 0 & 0 & Node\\
# + & - & 0 & 0 & Saddle\\
# - & - & 0 & 0 & Node\\
# + & + & + & + & Spiral\\
# - & - & + & + & Spiral\\
# 0 & 0 & + & + & Center\\
# \hline
# \end{array}
# $$

# %%
#Leave this empty!

# %% [markdown]
# # **Exercise 2 (*4.0 points*)**

# %% [markdown]
# 1) Give 5 examples of the coefficient matrix $A$ and initial condition $\textbf{x}_0$. Then use the formulae in Exercise 1 to find the solution $\textbf{x}$ explicitly. (*1.0 point*)

# %% [markdown]
# *Answer:*
#
#
# 0.   Sample example: $A = \begin{pmatrix} 1 & -1 \\ 2 & 1 \end{pmatrix}$ and $\textbf{x}_0 = \begin{pmatrix}1 \\ 1\end{pmatrix}$. Solution is
# $$
#   \textbf{x}(t) =   e^{t} \cos(\sqrt{2t}) \begin{pmatrix} 1 \\ 1  \end{pmatrix}  +  e^{0t} \sin(\sqrt{2t}) \begin{pmatrix} \ -1 \\ \sqrt{2}  \end{pmatrix}
# $$
# 1.   Example 1: $A = \begin{pmatrix} 2 & 3 \\ 5 & 4 \end{pmatrix}$ and $\textbf{x}_0 = \begin{pmatrix}1 \\ 1\end{pmatrix}$. Solution is
# $$
#   \textbf{x}(t) = \frac{-1}{4} e^{7t} \begin{pmatrix} -3 \\ -5 \end{pmatrix}  + \frac{1}{20} e^{-t} \begin{pmatrix} 5 \\ -5 \end{pmatrix}
# $$
# 2.   Example 2: $A = \begin{pmatrix} 1 & -2 \\ 2 & 4 \end{pmatrix}$ and $\textbf{x}_0 = \begin{pmatrix}1 \\ 1\end{pmatrix}$. Solution is
# $$
#   \textbf{x}(t) = \frac{3}{5} e^{5t} \begin{pmatrix} 1 \\ 2 \end{pmatrix}  + \frac{-1}{5} e^{0t} \begin{pmatrix} -2 \\ 1 \end{pmatrix}
# $$
# 3.   Example 3: $A = \begin{pmatrix} -3 & 12 \\ 2 & 8 \end{pmatrix}$ and $\textbf{x}_0 = \begin{pmatrix}1 \\ 1\end{pmatrix}$. Solution is
# $$
#  \textbf{x}(t) = \frac{5}{11} e^{0t} \begin{pmatrix} 4 \\ 1 \end{pmatrix}  + \frac{3}{11} e^{-11t} \begin{pmatrix} -3 \\ 2 \end{pmatrix}
# $$
# 4.   Example 4: $A = \begin{pmatrix} 3 & -1 \\ 2 & 1 \end{pmatrix}$ and $\textbf{x}_0 = \begin{pmatrix}1 \\ 1\end{pmatrix}$. Solution is
# $$
#   \textbf{x}(t) = e^{2t} \begin{pmatrix} \cos(t) \\ \cos(t) \end{pmatrix}  + e^{2t}  \begin{pmatrix} 1 \\ \sin(t) \end{pmatrix}
# $$
# 5.   Example 5: $A = \begin{pmatrix} 2 & -4 \\ 2 & -2 \end{pmatrix}$ and $\textbf{x}_0 = \begin{pmatrix}1 \\ 1\end{pmatrix}$. Solution is
# $$
#   \textbf{x}(t) = e^{0t} \begin{pmatrix} \cos(2t) \\ \cos(2t) \end{pmatrix} + e^{0t}  \begin{pmatrix} - \sin(2t) \\ 0 \end{pmatrix}
# $$

# %% [markdown]
# 2) Find the formula of the solution to system of "non-homogeneous" ODEs
# $$
# \begin{cases}
#   \dot{\textbf{x}} = A\textbf{x} + \textbf{f}(t),\\
#   \textbf{x}(0) = \textbf{x}_0,
# \end{cases}
# $$
# where $A$ is a $2\times 2$ matrix with real entries and $\textbf{f}$ is a 2-dimensional real-vector-valued function dependent on only $t$. (*1.5 point*)

# %% [markdown]
# *Answer:*
#
# Solution is
# $$
# \textbf{x}(t) = \phi(t)\phi^{-1}(0)\vec{x_0} + \int_0^t \phi(t)\phi^{-1}(s)\vec{f(s)}ds
# $$
#
# where $\Phi(t)$ is a fundamental matrix solution of the corresponding homogeneous system $\mathbf{x}'(t) = A \mathbf{x}(t)$. In other words:
#
#
# - $\Phi(t)$ satisfies $\Phi'(t) = A\Phi(t)$; that is, every column of $\Phi(t)$ solves the homogeneous system $\mathbf{x}'(t) = A \mathbf{x}(t)$.
#
#
# - $\Phi(t)$ is an invertible matrix for every $t$; that is, the $n$ columns of $\Phi(t)$ are linearly independent.

# %% [markdown]
# 3) Give two examples of Exercise 2.2. Then use the formula of the solution to find the solutions to the two examples. (*1.5 point*)

# %% [markdown]
# *Answer:*
#
#
#
# 0.   Sample example: $A = \begin{pmatrix} 1 & -1 \\ 2 & 1 \end{pmatrix}$, $\textbf{f}(t)=\begin{pmatrix} t, t^2 \end{pmatrix}$, and $\textbf{x}_0 = \begin{pmatrix}1 \\ 1\end{pmatrix}$. Solution is
# $$
#   \textbf{x}(t) =
# $$
# 1.   Example 1:
# 2.   Example 2:

# %%
#Leave this empty!

# %% [markdown]
# # **Exercise 3 (*4.0 points*)**

# %% [markdown]
# 1) Complete the codes below. Do not change the function prototypes! (*2.0 points*)

# %%
#Do not change these codes!
import numpy as np
from collections.abc import Callable

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12, 12)

Vector = np.array
Matrix = np.array
Function = Callable[[float, Vector], Vector]

# %%
#Give 5 examples so that at least 3 of them are nonlinear cases!
def example0(t: float, x: Vector) -> Vector:#Do not change this example
  """
  The definition of 2-dimensional real-vector-valued
  function f(t, x) in the ODE dx/dt = f(t, x)

  t: real number
  x: 2-dimensional real vector satisfying the ODE
  """
  constant_case = Matrix([[1., -1.], [2., 1.]], dtype=float)
  return np.matmul(constant_case, x)

def example1(t: float, x: Vector) -> Vector:
  pass

def example2(t: float, x: Vector) -> Vector:
  pass

def example3(t: float, x: Vector) -> Vector:
  pass

def example4(t: float, x: Vector) -> Vector:
  pass

def example5(t: float, x: Vector) -> Vector:
  pass

# %%
#Explicit Euler Algorithm
def explicit_euler(f: Function, t: float, x: Vector, h: float) -> Vector:
  """
  The approximate of the exact solution to the ODE dx/dt = f(t, x) at
  time t + h, x is the value of the solution at time t, h is the time step

  t: real number
  h: real number
  x: 2-dimensional real vector
  f: 2-dimensional real-vector-valued function 
  """
  y = np.zeros_like(x)
  y[0] = x[0] + h*f(t, x)[0]
  y[1] = x[1] + h*f(t, x)[1]
  return y
  pass

# %%
#The following functions are used to write the implicit Euler algorithm
def jacobian_x(f: Function, t: float, x: Vector, eps=1E-5) -> Matrix:
  """
  Return the numerical approximate of the Jacobian matrix of the
  2-dimensional real-vector-valued function f(t, x) with respect to x

  t: real number
  x: 2-dimensional real vector
  eps: infinitesimal constant of the approximation
  """
  n = len(x)
  J = np.zeros((n,n))
  for i in range(n):
    x_eps = x.copy()
    x_eps[i] += eps
    J[:, i] = (f(t, x_eps) - f(t, x)) / eps
  return J
  
  pass

def solve_system(A: Matrix, b: Vector) -> Vector:
  """
  Solution x to the system of linear equations Ax = b

  x: 2-dimensional real vector
  A: 2x2 matrix with real entries
  b: 2-dimensional real vector

  If the system does not have a solution, x will be the vector 0.
  """

  try:
    x = np.linalg.solve(A, b)
  except np.linalg.LinAlgError:
    x = np.zeros_like(b)
  return x
  pass

#Implicit Euler Arithm
def implicit_euler(f: Function, t: float, x: Vector, h: float) -> Vector:
  """
  The approximate of the exact solution to the ODE dx/dt = f(t, x) at
  time t + h, x is the value of the solution at time t, h is the time step

  t: real number
  h: real number
  x: 2-dimensional real vector
  f: 2-dimensional real-vector-valued function 
  """
  y = x.copy()
  for _ in range(30): # can change this number of Newton, t+h, y)
    A = np.eye(len(x)) - h * jacobian_x(f,t,x)
    b = y - h * f(t+h, y) - x
    y -= solve_system(A, b)
  return y

# %% [markdown]
# 2) Write codes to obtain a similar plot to the [plot](https://tinyurl.com/4fpt9xvk) of the example example0 where $A=\begin{pmatrix}1 & -1 \\ 2 & 1 \end{pmatrix}$ the initial value $\textbf{x}_0=\begin{pmatrix}1 \\ 1\end{pmatrix}$. The codes must also work for the other examples! (*2.0 points*)

# %%
#Plot here!
"""
  t: time
  x: value
"""
# Set the initial conditions
# x0 = np.array([1, 1]) # lotka_volterra initial
x0 = np.array([1, 1]) # example1 initial
# set time step
t0, tn = 0, 5
h = 0.01
# Create arrays to store the solution and time values
t = np.arange(t0, tn, h)
xe = np.zeros((len(t), 2))
xi = np.zeros((len(t), 2))

xi[0] = x0
xe[0] = x0
# Loop over time steps and approximate the solution using implicit Euler
for i in range(1, len(t)):
    xe[i] = explicit_euler(example0, t[i-1], xe[i-1], h)
    xi[i] = implicit_euler(example0, t[i-1], xi[i-1], h)
# Plot the solution
plt.plot(t*100, xe[:, 0], label='Romeo')
plt.plot(t*100, xe[:, 1], label='Juliet')
plt.ylim(-100,100)
plt.xlabel('Time')
plt.ylabel('x')
plt.legend()
plt.title("Explicit")
plt.show()

plt.plot(t*100, xi[:, 0], label='Romeo')
plt.plot(t*100, xi[:, 1], label='Juliet')
plt.ylim(-100,100)
plt.xlabel('Time')
plt.ylabel('x')
plt.legend()
plt.title("Implicit")
plt.show()


# Define a grid of x and y values
x_values = xe[:,0]
y_values = xe[:,1]


# Create a meshgrid for x and y values
x_grid = np.linspace(-100, 100, 25)
y_grid = np.linspace(-100, 100, 25)
X, Y = np.meshgrid(x_grid, y_grid)

# Calculate the vector field at each point in the meshgrid
u, v = np.zeros_like(X), np.zeros_like(Y)
NI, NJ = X.shape
for i in range(NI):
    for j in range(NJ):
        x, y = X[i, j], Y[i, j]
        xy_dot = example0(0, np.array([x, y]))
        u[i, j], v[i, j] = xy_dot[0], xy_dot[1]

# Plot the vector field as a quiver plot
fig, (ax1, ax2) = plt.subplots(1, 2)

# Plot the first subplot
ax1.plot(xe[:,0], xe[:,1], 'r', linewidth =2)
ax1.quiver(X, Y, u, v) #Vector Field
ax1.set_title('Explicit Phase Potrait')
ax1.set_xlim([-100, 100])
ax1.set_ylim([-100, 100])
ax1.set_xlabel("Romeo's Love")
ax1.set_ylabel("Juliet's Love")

# Plot the second subplot
ax2.plot(xi[:,0], xi[:,1], 'r', linewidth =2)
ax2.quiver(X, Y, u, v) #Vector Field
ax2.set_title('Implicit Phase Potrait')
ax2.set_xlabel("Romeo's Love")
ax2.set_ylabel("Juliet's Love")
ax2.set_xlim([-100, 100])
ax2.set_ylim([-100, 100])

# Set the aspect ratio to be equal for both subplots
ax1.set_aspect('equal')
ax2.set_aspect('equal')

# Show the plot
plt.show()
#Plot here!

# %%
#Leave this empty!

# %% [markdown]
# # **References**

# %% [markdown]
# List all of your references here!
#
#
# 1.   List item
# 2.   List item

# %% [markdown]
# ---

# %% [markdown]
# # Exercise 4 (Optional)
# You should provide the answer to this question as a separate Ipython notebook!

# %%
#Leave this empty!

# %% [markdown]
# ---
